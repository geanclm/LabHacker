# %% [markdown]
# # Title

# %%
# Campanha Nacional de Vacinação contra Covid-19

# %% [markdown]
# # Head

# %%
# Análise dos dados
# seguindo YouTube do LABHacker, porém com outra base de dados
# by geanclm in 01/03/2022 at 09:43h

# %% [markdown]
# # Import libs

# %%
import pandas as pd
# import requests

# %% [markdown]
# # Local files

# %%
# !dir
# Out:
#  O volume na unidade C ‚ Windows
#  O N£mero de S‚rie do Volume ‚ 2656-7D0D
#
#  Pasta de C:\Users\geanc\Downloads\DATA SCIENCE\LabHacker\VACINACAO
#
# 01/03/2022  09:42    <DIR>          .
# 01/03/2022  09:42    <DIR>          ..
# 01/03/2022  08:03    <DIR>          .ipynb_checkpoints
# 01/03/2022  09:42            37.105 Campanha_Nacional_Vacinacao_csv.ipynb
# 01/03/2022  08:35    <DIR>          data
# 01/03/2022  07:57     1.214.463.032 part-00002-8e72fd91-3825-4660-8b27-a35bb075e012.c000.csv
#                2 arquivo(s)  1.214.500.137 bytes
#                4 pasta(s)   623.973.617.664 bytes dispon¡veis

# %% [markdown]
# # Import data .json

# %%
# url = 'https://imunizacao-es.saude.gov.br/desc-imunizacao/_search'
# response = requests.get(url)

# %%
# - - -
# consulta sobre requests e autenticação
# https://docs.python-requests.org/pt_BR/latest/user/authentication.html
# - - -
# from requests.auth import HTTPDigestAuth
# url = 'https://imunizacao-es.saude.gov.br/_search'
# rq.get(url, auth=HTTPDigestAuth('imunizacao_public', 'qlto5t&7r_@+#Tlstigi'))

# %%
# response.text

# %%
# df = pd.DataFrame(response.json()['desc-imunizacao'])

# %% [markdown]
# # Import data .csv

# %%
# Registros de Vacinação COVID19 - PA até TO
# Dados PB - Parte 3
# fonte: https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao/resource/10aed154-04c8-4cf4-b78a-8f0fa1bc5af4

# by geanclm in 01/03/2022 at 08:06h
# Obs: No site do DataSUSa base de dados está segmentada em vários arquivos .csv
# devido a quantidade de dados relacionados a vacinação.
# Tarefa: verificar o acesso diretamente com a API utilizando o json

# %%
df = pd.read_csv('part-00002-8e72fd91-3825-4660-8b27-a35bb075e012.c000.csv',
                 sep=';',
                 encoding = 'utf-8',
                 low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2452588 entries, 0 to 2452587
# Data columns (total 32 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   document_id                               object
#  1   paciente_id                               object
#  2   paciente_idade                            float64
#  3   paciente_dataNascimento                   object
#  4   paciente_enumSexoBiologico                object
#  5   paciente_racaCor_codigo                   float64
#  6   paciente_racaCor_valor                    object
#  7   paciente_endereco_coIbgeMunicipio         object
#  8   paciente_endereco_coPais                  object
#  9   paciente_endereco_nmMunicipio             object
#  10  paciente_endereco_nmPais                  object
#  11  paciente_endereco_uf                      object
#  12  paciente_endereco_cep                     object
#  13  paciente_nacionalidade_enumNacionalidade  object
#  14  estabelecimento_valor                     int64
#  15  estabelecimento_razaoSocial               object
#  16  estalecimento_noFantasia                  object
#  17  estabelecimento_municipio_codigo          int64
#  18  estabelecimento_municipio_nome            object
#  19  estabelecimento_uf                        object
#  20  vacina_grupoAtendimento_codigo            int64
#  21  vacina_grupoAtendimento_nome              object
#  22  vacina_categoria_codigo                   float64
#  23  vacina_categoria_nome                     object
#  24  vacina_lote                               object
#  25  vacina_fabricante_nome                    object
#  26  vacina_fabricante_referencia              object
#  27  vacina_dataAplicacao                      object
#  28  vacina_descricao_dose                     object
#  29  vacina_codigo                             int64
#  30  vacina_nome                               object
#  31  sistema_origem                            object
# dtypes: float64(3), int64(4), object(25)
# memory usage: 598.8+ MB

# %%
df.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
#       dtype='object')

# %%
df.shape
# Out:
# (2452588, 32)

# %%
df.head(3)
# Out:
#                                  document_id  \
# 0  9de8cb9f-f038-48a3-b533-cbfb3ac605b9-i0b0
# 1  0770dce3-1d11-4124-bece-5e65951ee7bf-i0b0
# 2  9dfe9ad0-96fb-4e13-84a1-33851dc42c81-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  ef1814d7a955c92e3fcb73a51803d1e46b6de512107cea...            55.0
# 1  0ee3e365c308215a63e43eaf4c3290beda936d793db88e...            52.0
# 2  812bcc74d6e35605ad77771839c08011a9f34d915d72d6...            48.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1965-10-25                          F                     99.0
# 1              1969-08-04                          F                      3.0
# 2              1972-09-05                          M                      3.0
#
#   paciente_racaCor_valor paciente_endereco_coIbgeMunicipio  \
# 0         SEM INFORMACAO                               NaN
# 1                  PARDA                            250730
# 2                  PARDA                            251370
#
#   paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      NaN                           NaN  ...
# 1                       10                       JACARAU  ...
# 2                       10                    SANTA RITA  ...
#
#   vacina_categoria_codigo vacina_categoria_nome vacina_lote  \
# 0                     2.0          Faixa Etária      210279
# 1                     2.0          Faixa Etária      210334
# 2                     2.0          Faixa Etária     ABW4735
#
#   vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0       SINOVAC/BUTANTAN   Organization/61189445000156           2021-07-01
# 1       SINOVAC/BUTANTAN   Organization/61189445000156           2021-09-20
# 2            ASTRAZENECA   Organization/00394544000851           2021-06-15
#
#   vacina_descricao_dose  vacina_codigo                            vacina_nome  \
# 0               1ª Dose             86  COVID-19 SINOVAC/BUTANTAN - CORONAVAC
# 1               1ª Dose             86  COVID-19 SINOVAC/BUTANTAN - CORONAVAC
# 2               1ª Dose             89       COVID-19 ASTRAZENECA - ChAdOx1-S
#
#   sistema_origem
# 0       Novo PNI
# 1       Novo PNI
# 2       Novo PNI
#
# [3 rows x 32 columns]

# %%
# Obs: registro equivocado no campo
df['paciente_enumSexoBiologico'].value_counts()
# Out:
# F    1318664
# M    1133911
# I         10
# Name: paciente_enumSexoBiologico, dtype: int64

# %%
df[df['paciente_enumSexoBiologico']=='I']
# Out:
#                                        document_id  \
# 106437   416fefb3-fe76-4eae-b9ef-bfe9fa6f15d7-i0b0
# 132599   c8290056-e71c-4016-91c8-8254a63ee978-i0b0
# 326332   7c2a4c26-49c2-4f01-9711-87ecf87537d2-i0b0
# 394409   64dc726e-30b5-4132-b705-f40871ea2d8f-i0b0
# 1105703  0e6da947-42b3-4bb2-8ac4-050b61ab3f76-i0b0
# 1123158  04669db2-2205-47ba-825b-057ba00bca37-i0b0
# 1470559  985f12c7-2e36-470d-83d7-e621a5dd73ef-i0b0
# 1796438  7ffecb65-9d76-4c7f-b608-d0993d7622f9-i0b0
# 1804737  c5be39f5-6c47-4120-bc9f-886da42b3e60-i0b0
# 2440876  8973c853-c185-45ea-9a28-a06cfb274c33-i0b0
#
#                                                paciente_id  paciente_idade  \
# 106437   0af0ae533a1aa9585e5a80df7d73b1332844b3903aa8bf...            81.0
# 132599   bf72571c451e14d6f105e39b7ab4b464a7887811cc3e23...            44.0
# 326332   ad30fafc588177982963f15222b231dbf4c4d2617fd9e0...            50.0
# 394409   2594ac7f1f382f5f082dad68a3623df986dac7bd56b574...            75.0
# 1105703  fcf3bd28de3c3693ae034b89f86a0ab8ae6d03af977fb5...            53.0
# 1123158  342556842c1ef20cad7dff4fbd6ab3310c74b6ae80fcc2...             6.0
# 1470559  ad30fafc588177982963f15222b231dbf4c4d2617fd9e0...            51.0
# 1796438  c8d9cb3fdd20236192131d3da6ba9d65cad548605e9a4c...            12.0
# 1804737  fcf3bd28de3c3693ae034b89f86a0ab8ae6d03af977fb5...            53.0
# 2440876  398f553f59ff7f9696912785d415a841518c3963154e9f...            74.0
#
#         paciente_dataNascimento paciente_enumSexoBiologico  \
# 106437               1940-07-11                          I
# 132599               1976-06-14                          I
# 326332               1970-12-28                          I
# 394409               1946-01-08                          I
# 1105703              1967-10-29                          I
# 1123158              2015-05-15                          I
# 1470559              1970-12-28                          I
# 1796438              2009-11-06                          I
# 1804737              1967-10-29                          I
# 2440876              1947-06-24                          I
#
#          paciente_racaCor_codigo paciente_racaCor_valor  \
# 106437                       4.0                AMARELA
# 132599                       3.0                  PARDA
# 326332                       3.0                  PARDA
# 394409                       1.0                 BRANCA
# 1105703                      1.0                 BRANCA
# 1123158                     99.0         SEM INFORMACAO
# 1470559                      3.0                  PARDA
# 1796438                     99.0         SEM INFORMACAO
# 1804737                      1.0                 BRANCA
# 2440876                      5.0               INDIGENA
#
#         paciente_endereco_coIbgeMunicipio paciente_endereco_coPais  \
# 106437                             250380                       10
# 132599                             250350                       10
# 326332                             251250                       10
# 394409                             251065                       10
# 1105703                            250750                       10
# 1123158                            250890                       10
# 1470559                            251250                       10
# 1796438                            250320                       10
# 1804737                            250750                       10
# 2440876                            250905                       10
#
#         paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 106437                 CALDAS BRANDAO  ...                     2.0
# 132599              CACIMBA DE DENTRO  ...                     2.0
# 326332                      QUEIMADAS  ...                     2.0
# 394409                         PARARI  ...                     2.0
# 1105703                   JOAO PESSOA  ...                     1.0
# 1123158                    MAMANGUAPE  ...                     NaN
# 1470559                     QUEIMADAS  ...                     2.0
# 1796438                      CABEDELO  ...                     2.0
# 1804737                   JOAO PESSOA  ...                     1.0
# 2440876                      MARCACAO  ...                     7.0
#
#         vacina_categoria_nome vacina_lote vacina_fabricante_nome  \
# 106437           Faixa Etária      FM3802                 PFIZER
# 132599           Faixa Etária  214VCD082Z    ASTRAZENECA/FIOCRUZ
# 326332           Faixa Etária  214VCD105W    ASTRAZENECA/FIOCRUZ
# 394409           Faixa Etária      210043       SINOVAC/BUTANTAN
# 1105703          Comorbidades  216VCD185W    ASTRAZENECA/FIOCRUZ
# 1123158                   NaN  C202107128       SINOVAC/BUTANTAN
# 1470559          Faixa Etária      FL4222                 PFIZER
# 1796438          Faixa Etária      FH4750                 PFIZER
# 1804737          Comorbidades  214vcd051z    ASTRAZENECA/FIOCRUZ
# 2440876       Povos Indígenas     211A21A                JANSSEN
#
#          vacina_fabricante_referencia vacina_dataAplicacao  \
# 106437             Organization/28290           2021-12-02
# 132599               Organization/149           2021-06-08
# 326332               Organization/149           2021-09-08
# 394409    Organization/61189445000156           2021-03-05
# 1105703   Organization/33781055006761           2021-08-19
# 1123158              Organization/152           2022-02-11
# 1470559            Organization/28290           2022-01-13
# 1796438   Organization/00394544000851           2021-11-13
# 1804737   Organization/33781055006761           2021-05-05
# 2440876   Organization/00394544000851           2021-10-15
#
#         vacina_descricao_dose  vacina_codigo  \
# 106437                Reforço             87
# 132599                1ª Dose             85
# 326332                2ª Dose             85
# 394409                1ª Dose             86
# 1105703               2ª Dose             85
# 1123158               1ª Dose             86
# 1470559               Reforço             87
# 1796438               1ª Dose             87
# 1804737               1ª Dose             85
# 2440876               Reforço             88
#
#                                        vacina_nome      sistema_origem
# 106437                 COVID-19 PFIZER - COMIRNATY            Novo PNI
# 132599   COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD            Novo PNI
# 326332   COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD            Novo PNI
# 394409       COVID-19 SINOVAC/BUTANTAN - CORONAVAC            Novo PNI
# 1105703  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD  Vacina João Pessoa
# 1123158      COVID-19 SINOVAC/BUTANTAN - CORONAVAC            Novo PNI
# 1470559                COVID-19 PFIZER - COMIRNATY            Novo PNI
# 1796438                COVID-19 PFIZER - COMIRNATY            Novo PNI
# 1804737  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD  Vacina João Pessoa
# 2440876             COVID-19 JANSSEN - Ad26.COV2.S            Novo PNI
#
# [10 rows x 32 columns]
